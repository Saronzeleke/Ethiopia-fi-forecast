# %%
from src.data_enricher import DataEnricher
from src.data_loader import DataLoader

# Load → Enrich → Save
loader = DataLoader()
data = loader.load_data(...)['data']

enricher = DataEnricher(data)
# Run enrichment methods
enriched = enricher.get_enriched_data()
enriched.to_csv('data/processed/enriched_data.csv')
